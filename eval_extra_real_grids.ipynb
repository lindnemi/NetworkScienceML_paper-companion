# %%
import pandas as pd
# ignore future warnings, some code needs to be updated when packages are updated!
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import os
import csv
import h5py
import numpy as np
from joblib import load

from sklearn.metrics import r2_score
from tools import add_interactions

# %%
work_dir = "/home/mlindner/coen/micha/netsci_vs_gnn/"

model_infos = []

for root, dirs, files in os.walk(work_dir + "models_paper"):

    for file in files:
        if file.endswith(".csv") and not file.startswith("gnn") and not "extended" in file:
            with open(os.path.join(root, file), 'r') as data:
                model_infos.append(list(csv.DictReader(data))[0])
_mi = pd.DataFrame(model_infos)

# %%
mi = _mi[(_mi["task"] == "SNBS")]

# %%
datapath = "/p/projects/coen/christian/datasets/snbs_homogeneous_dataset/single_files_netsci/"

for country in ["elmod", "osf_france",  "osf_gb",  "osf_spain",  "texas"]:
    
    print(country)
        
    hf = h5py.File(datapath + country + "/snbs.h5", 'r')
    y = np.array(hf.get(list(hf.keys())[0])).flatten()
    hf.close()
            

    X = pd.read_csv(datapath + country + "/input_features.csv").drop(columns=["node_cat", "proper leaf"])

    
    if country not in ["texas"]:
        X = X.drop(columns=["neighbor_degree_mean"])


    Xinter = add_interactions(X.drop(columns=["backup_capacity", "maximal_line_load_post_dc"]))
    
    for i in mi.index:
        
        model = load(mi["model_path"][i] + "model.joblib")
        
        # It's important to scale the model data with the StandardScaler (model[0])
        if mi["with_interactions"][i]=="True":
            model[0].fit(Xinter)
        else:
            model[0].fit(X)
        
        if mi["model_name"][i] in ["GradientBoostingClassifierSNBS", "LogisticRegressionSNBS"]:
            
            print("Classifier")
            
            if mi["with_interactions"][i]=="True":
                ev_r2 = r2_score(y, model.predict_proba(Xinter)[:, 1])
                
            else:
                ev_r2 = r2_score(y, model.predict_proba(X)[:, 1])
                    
        else:    
            
            print("Regressor")

            if mi["with_interactions"][i]=="True":         
                ev_r2 = r2_score(y, model.predict(Xinter))
            else:
                ev_r2 = r2_score(y, model.predict(X))
                
        print(mi["model_name"][i], " tr", mi["nodes_per_grid"][i], ": ", 
              ev_r2)

        _mi.at[i,"ev_" + country + "_r2"] = ev_r2
# Out:
# elmod
# Regressor
# omp1LinearSNBS  tr 100 :  0.24837598511877002
# Regressor
# omp1LinearSNBS  tr 20 :  -0.386731356194576
# Regressor
# omp1LinearSNBS  tr 100 :  0.25540750039775617
# Regressor
# omp1LinearSNBS  tr 20 :  -0.026926060722210376
# Regressor
# omp1LinearSNBS  tr 100 :  0.25887503067449635
# Regressor
# omp1LinearSNBS  tr 20 :  -0.3473317192304677
# Regressor
# omp1LinearSNBS  tr 100 :  0.14557955814793222
# Regressor
# omp1LinearSNBS  tr 20 :  -0.1533072375481146
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.051291036023501824
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.5325369705728416
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.5325369705728416
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.051291036023501824
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.6030478219891748
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.06018632882505315
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.15506306912271361
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.5763372835884972
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.15506306912271361
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.46104146012037883
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.07970732715828266
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.46104146012037883
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.5712910453274161
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.5325369705728416
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.051291036023501824
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.051291036023501824
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.5325369705728416
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.051291036023501824
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.5883593593085016
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.07970732715828266
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.5763372835884972
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.15506306912271361
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.15506306912271361
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.5763372835884972
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.5763372835884972
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.15506306912271361
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.06018632882505315
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.06018632882505315
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.6012743548297595
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.596795274171904
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.06018632882505315
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.06018632882505315
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.5325369705728416
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.46104146012037883
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.07970732715828266
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.07970732715828266
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.46104146012037883
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.46104146012037883
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.07970732715828266
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.5763372835884972
# Regressor
# omp5LinearSNBS  tr 100 :  0.43131852918884084
# Regressor
# omp5LinearSNBS  tr 20 :  -0.05631283267723686
# Regressor
# omp5LinearSNBS  tr 100 :  0.4360247357051973
# Regressor
# omp5LinearSNBS  tr 20 :  0.009745755790171451
# Regressor
# omp5LinearSNBS  tr 100 :  0.4205260260389665
# Regressor
# omp5LinearSNBS  tr 20 :  0.011134596242236228
# Regressor
# omp5LinearSNBS  tr 100 :  0.48647573352497786
# Regressor
# omp5LinearSNBS  tr 20 :  -0.088729141601958
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.31537232660356795
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.2817022428555168
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.281650763339226
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.31539411608537005
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.3912865729337902
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.028224263762610002
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.11234889682784754
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.3594929625956689
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.11234889683747373
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.3204892798435679
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.42128687962388445
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.32048927984356634
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.4049672667559602
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.2816507633392259
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.31539411608537005
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.31537232660356795
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.28165076333922345
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.31539411608537016
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.40652525399273465
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.42128687962388445
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.35949296261023034
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.11234896695501206
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.11234889682784688
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.3594929626104526
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.3594929625963207
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.11234889683516869
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.10514989341904113
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.12072786813526304
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.4008655622233884
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.43547749791343904
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.12678949470327772
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.11455727094651236
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.28170224284729606
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.3204892798435667
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.42128687962388445
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.42128687962388445
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.320489279843567
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.3204892798435669
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.42128687962388445
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.3594929625744918
# Regressor
# omp2LinearSNBS  tr 100 :  0.26932519294657464
# Regressor
# omp2LinearSNBS  tr 20 :  -0.15647232961025037
# Regressor
# omp2LinearSNBS  tr 100 :  0.27827559502959476
# Regressor
# omp2LinearSNBS  tr 20 :  -0.012370604491747095
# Regressor
# omp2LinearSNBS  tr 100 :  0.28174648111431067
# Regressor
# omp2LinearSNBS  tr 20 :  -0.153352317747387
# Regressor
# omp2LinearSNBS  tr 100 :  0.3130523327737168
# Regressor
# omp2LinearSNBS  tr 20 :  -0.14547679873345043
# Regressor
# LinearRegressionSNBS  tr 100 :  -3.58988944404263e+20
# Regressor
# LinearRegressionSNBS  tr 20 :  -6.189088091626456e+20
# Regressor
# LinearRegressionSNBS  tr 100 :  -1.755703757166294e+18
# Regressor
# LinearRegressionSNBS  tr 20 :  -3829009204363.309
# Regressor
# LinearRegressionSNBS  tr 100 :  -1.0222246895824968e+20
# Regressor
# LinearRegressionSNBS  tr 20 :  -3.246548412430566e+18
# Regressor
# LinearRegressionSNBS  tr 100 :  -1535023003316356.0
# Regressor
# LinearRegressionSNBS  tr 20 :  -1.7121358409110087e+21
# Classifier
# LogisticRegressionSNBS  tr 100 :  -12.003757558543555
# Classifier
# LogisticRegressionSNBS  tr 20 :  -15.117412556246773
# Classifier
# LogisticRegressionSNBS  tr 100 :  -6.694131634747485
# Classifier
# LogisticRegressionSNBS  tr 20 :  -8.064828759026993
# Classifier
# LogisticRegressionSNBS  tr 100 :  -4.449040113468456
# Classifier
# LogisticRegressionSNBS  tr 20 :  -3.620270211894364
# Classifier
# LogisticRegressionSNBS  tr 100 :  -14.668202101519924
# Classifier
# Regressor
# LinearRegressionSNBS  tr 20 :  -1.0379360396011577e+21
# Regressor
# LinearRegressionSNBS  tr 100 :  -1.836093700529638e+18
# Regressor
# LinearRegressionSNBS  tr 20 :  -4649951688859.367
# Regressor
# LinearRegressionSNBS  tr 100 :  -8.180018446871265e+19
# Regressor
# LinearRegressionSNBS  tr 20 :  -3.9885387204506035e+18
# Regressor
# LinearRegressionSNBS  tr 100 :  -2167213319206057.8
# Regressor
# LinearRegressionSNBS  tr 20 :  -5.391591769103078e+21
# Classifier
# LogisticRegressionSNBS  tr 100 :  -9.869601970089004
# Classifier
# LogisticRegressionSNBS  tr 20 :  -14.403904219049057
# Classifier
# LogisticRegressionSNBS  tr 100 :  -5.542607061851933
# Classifier
# LogisticRegressionSNBS  tr 20 :  -10.298775156031333
# Classifier
# LogisticRegressionSNBS  tr 100 :  -1.3783415529169667
# Classifier
# LogisticRegressionSNBS  tr 20 :  -0.7586925994623166
# Classifier
# LogisticRegressionSNBS  tr 100 :  -19.34605222554446
# Classifier
# LogisticRegressionSNBS  tr 20 :  -6.685840547155823
# osf_gb
# Regressor
# omp1LinearSNBS  tr 100 :  -0.4777377250254413
# Regressor
# omp1LinearSNBS  tr 20 :  -0.38502099263242817
# Regressor
# omp1LinearSNBS  tr 100 :  -0.5127762828042566
# Regressor
# omp1LinearSNBS  tr 20 :  -0.08940221625579348
# Regressor
# omp1LinearSNBS  tr 100 :  -0.5175843523264914
# Regressor
# omp1LinearSNBS  tr 20 :  -0.3408338492821039
# Regressor
# omp1LinearSNBS  tr 100 :  -0.6505693679779418
# Regressor
# omp1LinearSNBS  tr 20 :  0.32646201269607067
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.14404094780721644
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.740607529185906
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.740607529185906
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.14404094780721644
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.7705335246354268
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.17501883925972883
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.17003335110998408
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.7667290447279385
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.17003335110998408
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.913690143397154
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.25206456785750153
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.913690143397154
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.8073243764475702
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.740607529185906
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.14404094780721644
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.14404094780721644
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.740607529185906
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.14404094780721644
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.8664630695400366
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.25206456785750153
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.7667290447279385
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.17003335110998408
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.17003335110998408
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.7667290447279385
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.7667290447279385
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.17003335110998408
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.17501883925972883
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.17501883925972883
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.8463284276099794
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.8082303734959699
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.17501883925972883
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.17501883925972883
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.740607529185906
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.913690143397154
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.25206456785750153
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.25206456785750153
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.913690143397154
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.913690143397154
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  0.25206456785750153
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  -0.7667290447279385
# Regressor
# omp5LinearSNBS  tr 100 :  -0.4980196481317296
# Regressor
# omp5LinearSNBS  tr 20 :  0.1645436810681863
# Regressor
# omp5LinearSNBS  tr 100 :  -0.5299951035969463
# Regressor
# omp5LinearSNBS  tr 20 :  0.154978554081174
# Regressor
# omp5LinearSNBS  tr 100 :  -0.6008338917981317
# Regressor
# omp5LinearSNBS  tr 20 :  0.14314052070970562
# Regressor
# omp5LinearSNBS  tr 100 :  -0.6231277564408466
# Regressor
# omp5LinearSNBS  tr 20 :  0.33108452226164187
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.31146592894057057
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.82223961469755
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.8213891461124478
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.3114743621946998
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.0376127827286186
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.20212732706895098
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.3470407259491277
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.0692608230261027
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.34704072606116254
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -2.0243816323534376
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.342330491553948
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -2.0243816323534385
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -0.8490691063924898
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.82138914611247
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.3114607888755614
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.3114674151454
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.8213891461124723
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.31145802324573757
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -0.9249514124884728
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.342330491553948
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.0692608232011893
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.34704072594913615
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.34704072594913216
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.0692608232071028
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.0692608230270157
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.34704072606076575
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.2204177234174196
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.22657044545968508
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -0.8918793971570969
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -0.9009433755644336
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.17970460717652648
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.11938646327948055
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.8222396146772084
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -2.02438163235344
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.342330491553948
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.342330491553948
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -2.0243816323534407
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -2.02438163235344
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.342330491553948
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.0692608230031313
# Regressor
# omp2LinearSNBS  tr 100 :  -0.6019334081770347
# Regressor
# omp2LinearSNBS  tr 20 :  -0.33018992278706927
# Regressor
# omp2LinearSNBS  tr 100 :  -0.6254926608159594
# Regressor
# omp2LinearSNBS  tr 20 :  0.1369297293150734
# Regressor
# omp2LinearSNBS  tr 100 :  -0.6273066551946682
# Regressor
# omp2LinearSNBS  tr 20 :  -0.023842564262717136
# Regressor
# omp2LinearSNBS  tr 100 :  -0.7262958122443632
# Regressor
# omp2LinearSNBS  tr 20 :  0.3445436811939291
# Regressor
# LinearRegressionSNBS  tr 100 :  -1.0818018931095992e+21
# Regressor
# LinearRegressionSNBS  tr 20 :  -7.287223752278376e+21
# Regressor
# LinearRegressionSNBS  tr 100 :  -8.378991279503843e+18
# Regressor
# LinearRegressionSNBS  tr 20 :  -7223170694818.555
# Regressor
# LinearRegressionSNBS  tr 100 :  -5.058831520863228e+20
# Regressor
# LinearRegressionSNBS  tr 20 :  -1.932709741663705e+19
# Regressor
# LinearRegressionSNBS  tr 100 :  -8767073802629572.0
# Regressor
# LinearRegressionSNBS  tr 20 :  -5.136753100456782e+21
# Classifier
# LogisticRegressionSNBS  tr 100 :  -26.183098528015936
# Classifier
# LogisticRegressionSNBS  tr 20 :  -36.95538391888581
# Classifier
# LogisticRegressionSNBS  tr 100 :  -14.406428098236525
# Classifier
# LogisticRegressionSNBS  tr 20 :  -17.37427057768002
# Classifier
# LogisticRegressionSNBS  tr 100 :  -10.4193283871449
# Classifier
# LogisticRegressionSNBS  tr 20 :  -9.709518309720613
# Classifier
# LogisticRegressionSNBS  tr 100 :  -30.97829367586257
# Classifier
# LogisticRegressionSNBS  tr 20 :  -23.97942858282567
# osf_spain
# Regressor
# omp1LinearSNBS  tr 100 :  0.23151502760835385
# Regressor
# omp1LinearSNBS  tr 20 :  -0.5360879740619948
# Regressor
# omp1LinearSNBS  tr 100 :  0.2536228828796824
# Regressor
# omp1LinearSNBS  tr 20 :  -0.19769835013085602
# Regressor
# omp1LinearSNBS  tr 100 :  0.26327539046721526
# Regressor
# omp1LinearSNBS  tr 20 :  -0.47631422792736
# Regressor
# omp1LinearSNBS  tr 100 :  0.3477361812736972
# Regressor
# omp1LinearSNBS  tr 20 :  -0.5370736526154352
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.4303386315346944
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.4838645001801867
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.4838645001801867
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.4303386315346944
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.2917436500191152
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.0764745406077465
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.0045788281181200485
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.1819043280445144
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.0045788281181200485
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.3271255369918252
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.27341486756226185
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.3271255369918252
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.2748532047310268
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.4838645001801867
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.4303386315346944
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.4303386315346944
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.4838645001801867
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.4303386315346944
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.2576225860811171
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.27341486756226185
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.1819043280445144
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.0045788281181200485
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.0045788281181200485
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.1819043280445144
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.1819043280445144
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.0045788281181200485
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.0764745406077465
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.0764745406077465
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.2731434128709378
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.2562007065156495
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.0764745406077465
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.0764745406077465
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.4838645001801867
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.3271255369918252
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.27341486756226185
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.27341486756226185
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.3271255369918252
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.3271255369918252
# Regressor
# GradientBoostingRegressionSNBS  tr 20 :  -0.27341486756226185
# Regressor
# GradientBoostingRegressionSNBS  tr 100 :  0.1819043280445144
# Regressor
# omp5LinearSNBS  tr 100 :  0.2522722005273278
# Regressor
# omp5LinearSNBS  tr 20 :  -0.33108141035514094
# Regressor
# omp5LinearSNBS  tr 100 :  0.2777353351855437
# Regressor
# omp5LinearSNBS  tr 20 :  -0.21912213472539666
# Regressor
# omp5LinearSNBS  tr 100 :  0.3074693730175355
# Regressor
# omp5LinearSNBS  tr 20 :  -0.24671852490695034
# Regressor
# omp5LinearSNBS  tr 100 :  0.3868767361934551
# Regressor
# omp5LinearSNBS  tr 20 :  -0.6173719665074753
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.2149615013772932
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.6886268676720404
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.6895899461287631
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.21497684894816393
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.42193980233354267
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.19707792268544633
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.19506444900401865
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.3449654979864506
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.19506444890563956
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.6855892664982116
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.2575304873540074
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.6855892664982117
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.4381025640587851
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.6895899461287557
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.2150016781660813
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.21496148542061877
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.6895899461287539
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.21500123519468295
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.44635023839959753
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.2575304873540074
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.3449654979943376
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.19506444900402042
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.1950644490040191
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.344965498012473
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.34496549798583687
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.19506444890606478
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.17333454547317817
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.12244142671491587
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.39158669252637446
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.42742781502591354
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.10188498987859473
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  0.15852761767888934
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.6886268676728025
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.6855892664982115
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.2575304873540074
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.2575304873540074
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.6855892664982115
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.6855892664982117
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.2575304873540074
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  0.34496549802372467
# Regressor
# omp2LinearSNBS  tr 100 :  0.2724976234968456
# Regressor
# omp2LinearSNBS  tr 20 :  -0.3059263831238821
# Regressor
# omp2LinearSNBS  tr 100 :  0.2965698972363311
# Regressor
# omp2LinearSNBS  tr 20 :  -0.19257126267904612
# Regressor
# omp2LinearSNBS  tr 100 :  0.30669978498914474
# Regressor
# omp2LinearSNBS  tr 20 :  -0.29583007594159727
# Regressor
# omp2LinearSNBS  tr 100 :  0.4015890929632384
# Regressor
# omp2LinearSNBS  tr 20 :  -0.5376117364684176
# Regressor
# LinearRegressionSNBS  tr 100 :  -2.4764858784545122e+20
# Regressor
# LinearRegressionSNBS  tr 20 :  -5.045120253687117e+21
# Regressor
# LinearRegressionSNBS  tr 100 :  -2.764726295627478e+18
# Regressor
# LinearRegressionSNBS  tr 20 :  -2780803807931.3447
# Regressor
# LinearRegressionSNBS  tr 100 :  -1.0019617705311776e+20
# Regressor
# LinearRegressionSNBS  tr 20 :  -1.0772059773436756e+19
# Regressor
# LinearRegressionSNBS  tr 100 :  -3.676555870715883e+16
# Regressor
# LinearRegressionSNBS  tr 20 :  -7.6794000004556e+21
# Classifier
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.3678749631209026
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.7795190981004048
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.08164943811311831
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.08164943811311831
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.7795190981004048
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.7795190981004048
# Classifier
# GradientBoostingClassifierSNBS  tr 20 :  -0.08164943811311831
# Classifier
# GradientBoostingClassifierSNBS  tr 100 :  -1.1429177132168284
# Regressor
# omp2LinearSNBS  tr 100 :  0.09789768715533964
# Regressor
# omp2LinearSNBS  tr 20 :  -0.03885961698165663
# Regressor
# omp2LinearSNBS  tr 100 :  0.08526395835837208
# Regressor
# omp2LinearSNBS  tr 20 :  0.09190329412139864
# Regressor
# omp2LinearSNBS  tr 100 :  0.07987303270476809
# Regressor
# omp2LinearSNBS  tr 20 :  -0.018347035417834556
# Regressor
# omp2LinearSNBS  tr 100 :  -0.07219848500061565
# Regressor
# omp2LinearSNBS  tr 20 :  0.16171277788866634
# Regressor
# LinearRegressionSNBS  tr 100 :  -3.094301813811815e+20
# Regressor
# LinearRegressionSNBS  tr 20 :  -2.0857627555087508e+21
# Regressor
# LinearRegressionSNBS  tr 100 :  -3.636577143009337e+17
# Regressor
# LinearRegressionSNBS  tr 20 :  -7358082849531.4795
# Regressor
# LinearRegressionSNBS  tr 100 :  -6.06378313715244e+19
# Regressor
# LinearRegressionSNBS  tr 20 :  -2.5385062603657344e+18
# Regressor
# LinearRegressionSNBS  tr 100 :  -3674064833728878.0
# Regressor
# LinearRegressionSNBS  tr 20 :  -7.581988376780548e+21
# Classifier
# LogisticRegressionSNBS  tr 100 :  -14.969503924314763
# Classifier
# LogisticRegressionSNBS  tr 20 :  -21.562501641401834
# Classifier
# LogisticRegressionSNBS  tr 100 :  -9.27057591516633
# Classifier
# LogisticRegressionSNBS  tr 20 :  -7.6984401867652075
# Classifier
# LogisticRegressionSNBS  tr 100 :  -5.836296464483023
# Classifier
# LogisticRegressionSNBS  tr 20 :  -2.2652203911825386
# Classifier
# LogisticRegressionSNBS  tr 100 :  -15.816303078515997
# Classifier
# LogisticRegressionSNBS  tr 20 :  -8.00006526637097

# %%
i=43
_mi.loc[i,:]
# Out:
# model_name                                                   omp1LinearSNBS
# model                     Pipeline(steps=[('standardscaler', StandardSca...
# scaler                                                     StandardScaler()
# task                                                                   SNBS
# random_state
# datetime                                         2023-05-04 15:36:57.968421
# nodes_per_grid                                                           20
# features_path             /home/mlindner/coen/micha/netsci_vs_gnn/grids2...
# labels_path               /home/mlindner/coen/micha/netsci_vs_gnn/grids2...
# train_r2                                                 0.4233669406768461
# ev20_r2                                                  0.4274297177257468
# ev100_r2                                                 0.3415478778557044
# evTex_r2                                              0.0004000469460393452
# train_f2
# ev20_f2
# ev100_f2
# evTex_f2
# train_recall
# ev20_recall
# ev100_recall
# evTex_recall
# sparse_predictors         Index(['second_order_centrality root'], dtype=...
# training_time                                            0.9491145610809326
# with_interactions                                                      True
# train_idx                           RangeIndex(start=0, stop=14000, step=1)
# num_grids_for_training                                                700.0
# val_idx
# test20_idx                    RangeIndex(start=170000, stop=200000, step=1)
# test100_idx                  RangeIndex(start=850000, stop=1000000, step=1)
# gitsha                             09101f324dc4a21f0af780e5da4c8212be533d04
# gitdiff
# gitbranch                                                             paper
# gitremote                 git@gitlab.pik-potsdam.de:mlindner/netsci_vs_g...
# hostname                                                       cs-f14c01b04
# model_path                /home/mlindner/coen/micha/netsci_vs_gnn/models...
# script_path                   /p/projects/coen/micha/netsci_vs_gnn/tools.py
# ev_elmod_r2                                                       -0.026926
# ev_osf_france_r2                                                   0.238418
# ev_osf_gb_r2                                                      -0.089402
# ev_osf_spain_r2                                                   -0.197698
# ev_texas_r2                                                          0.0004
# Name: 43, dtype: object

# %%
_mi.to_csv(work_dir + "models_paper/model_info_extended.csv", index=False)

# %% [markdown]
# # OLD

# %%
if False:
    datapath = "/p/projects/coen/christian/datasets/snbs_homogeneous_dataset/single_files_netsci/"

    for country in ["elmod", "osf_france",  "osf_gb",  "osf_spain",  "texas"]:

        print(country)

        if country == "ds20/test":
            hf = h5py.File("/home/mlindner/coen/micha/netsci_vs_gnn/grids20/snbs_complete.h5", 'r')
            y = np.array(hf.get(list(hf.keys())[0])).flatten()
            hf.close()
            y = y[int(len(y) * 0.85):]
        else:
            hf = h5py.File(datapath + country + "/snbs.h5", 'r')
            y = np.array(hf.get(list(hf.keys())[0])).flatten()
            hf.close()


        if country == "ds20/test":
            _X = pd.read_csv("/home/mlindner/coen/micha/netsci_vs_gnn/grids20/network_measures_final.csv").drop(
                columns=["node_cat", "proper leaf"])
            Xtrain = _X.iloc[:int(len(_X) * 0.7)]
            X = _X.iloc[int(len(_X) * 0.85):]
        else:
            X = pd.read_csv(datapath + country + "/input_features.csv").drop(columns=["node_cat", "proper leaf"])


        if country not in ["texas", "ds20/test"]:
            X = X.drop(columns=["neighbor_degree_mean"])

        #_Xinter = add_interactions(_X.drop(columns=["backup_capacity", "maximal_line_load_post_dc"]))

        Xinter = add_interactions(X.drop(columns=["backup_capacity", "maximal_line_load_post_dc"]))

        _mi["ev_" + country + "_r2"] = None

        for i in mi.index:
            model = load(mi["model_path"][i] + "model.joblib")
            if mi["with_interactions"][i]=="True":
                model[0].fit(Xinter)
            else:
                model[0].fit(X)

            if mi["model_name"][i] in ["GradientBoostingClassifierSNBS", "LogisticRegressionSNBS"]:
                print("Classifier")
                if mi["with_interactions"][i]=="True":
                    ev_r2 = r2_score(y, model.predict_proba(Xinter)[:, 1])
                    print(mi["model_name"][i], " tr", mi["nodes_per_grid"][i], ": ", 
                          ev_r2)
                    _mi.loc[i,"ev_" + country + "_r2"] = ev_r2
                else:
                    ev_r2 = r2_score(y, model.predict_proba(X)[:, 1])
                    print(mi["model_name"][i], " tr", mi["nodes_per_grid"][i], ": ", 
                          ev_r2)
                    _mi.loc[i,"ev_" + country + "_r2"] = ev_r2

            else:    
                print("Regressor")

                if mi["with_interactions"][i]=="True":
                    ev_r2 = r2_score(y, model.predict(Xinter))
                    print(mi["model_name"][i], " tr", mi["nodes_per_grid"][i], ": ", 
                          ev_r2)
                    _mi.loc[i,"ev_" + country + "_r2"] = ev_r2
                else:
                    ev_r2 = r2_score(y, model.predict(X))
                    print(mi["model_name"][i], " tr", mi["nodes_per_grid"][i], ": ", 
                          ev_r2)
                    _mi.loc[i,"ev_" + country + "_r2"] = ev_r2
